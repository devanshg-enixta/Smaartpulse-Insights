# %%
import pandas as pd

# %%
source = pd.read_csv("lipsticks_source_reviews_new_19-1-2018.txt",sep='~')
tree = pd.read_csv("treemap_outputfile_mapped_2018-1-25_lipsticks_sentiment_hul.txt",sep='~')

# %%
source=source.drop_duplicates()

# %%
tree = tree[tree.aspect!=' all ']

# %%
tree.aspect.unique()
# Out:
# array([' ease-of-usage ', ' reliability ', ' effect-on-skin ',
#        ' service ', ' durability ', ' vfm ', ' style '], dtype=object)

# %%
out_prod=[]
for row in source.to_dict("records"):
    row['product_name'] = row['product_name'].lower()
    row['product_name'] = row['product_name'].replace('maybeline',"maybelline").replace('l-oreal',"loreal").replace('e-l-f',"elf").replace('v-color',"").replace('m-n-mn',"mn").replace('m-a-c',"mac").replace('k-veda',"KVeda").replace('l-a-girl',"l_a_girl").replace('7-heaven',"7_heaven").replace('7heavens',"7_heaven").replace('7-heavens',"7_heaven").replace('c-a-l-los-angeles',"c_a_l_los_angeles").replace('c-l-los-angeles',"c_a_l_los_angeles").replace(" ","-").lower()
    x = row['product_name'].split('-', 1)
    #x = x.split(' ')
    row['company'] = x[0].lower()
    out_prod.append(row)
mapped_comp_source=pd.DataFrame(out_prod)

# %%
mapped_comp = mapped_comp_source.company.unique()
#mapped_comp

# %%
test = mapped_comp_source[mapped_comp_source.company == 'clinique']
test.review_date.unique()
# Out:
# array(['7 Aug, 2015', '23 Jun, 2015', '13 Sep, 2016', '2016-03-30',
#        '2016-08-06'], dtype=object)

# %%
import pandas as pd
date = pd.to_datetime("2016-08-06")
# Out:
# Timestamp('2016-08-06 00:00:00')

# %%
import calendar
import datetime
import dateutil
today = datetime.datetime.now()
i=1
out_t=pd.DataFrame()
colum = ["Brand_name","Total_Number_of_Reviews","review_date","Month","Year"]
for c in mapped_comp:
    i=0
    print c
    comp_rev = mapped_comp_source[mapped_comp_source.company == c]
    comp_rev['review_date'] =pd.to_datetime(comp_rev['review_date'])
    date_df= comp_rev.sort_values(by='review_date')
    date_df = date_df[date_df.review_date  > '2017-01-02']
    if date_df.empty:
        continue
    else:
        a = date_df['review_date'].groupby(date_df.review_date.dt.to_period("M")).agg('count')
        a = pd.DataFrame(a).rename(columns={'review_date':'Total_Number_of_Reviews'}).reset_index(drop=False)
        a['Brand_name'] = c
        a['Year'] = a['review_date'].dt.year
        a['Month'] = a['review_date'].dt.month
        out_t = pd.concat([out_t,a])

# %%
lis= ['maybelline','loreal','lakme','mac','colorbar']
out_t_t = out_t[out_t['Brand_name'].isin(lis)]

# %%
out_t_t.to_csv("1_task_12_months_review_brand_wise_lipsticks_new.csv",index=False,columns =colum)

# %%
del tree['source']

# %%
out_prod_tree_date = tree.merge(mapped_comp_source[['source_review_id','review_date','company','source']], left_on='source_review_id', right_on='source_review_id')

# %%
lis= ['maybelline','loreal','lakme','mac','colorbar']
t1 = out_t[out_t['Brand_name'].isin(lis)]

# %%
i=1
out_t_sent=pd.DataFrame()
map_comp_tree = out_prod_tree_date.company.unique()
#print map_comp_tree
for c in map_comp_tree:
    i=0
   # print c
    comp_rev = out_prod_tree_date[out_prod_tree_date.company == c]
    comp_rev['review_date'] =pd.to_datetime(comp_rev['review_date'])
    date_df= comp_rev.sort_values(by='review_date')
    date_df = date_df[date_df.sentiment_type == 'positive']
    date_df = date_df[date_df.review_date  > '2017-01-02']
    a= date_df[date_df.sentiment_type == 'positive']
    if date_df.empty:
        continue
    else:
        a = a['review_date'].groupby(a.review_date.dt.to_period("M")).agg('count')
        a = pd.DataFrame(a).rename(columns={'review_date':'Total_Number_of_PositiveReviews'}).reset_index(drop=False)
        a['Brand_name'] = c
        a['Year'] = a['review_date'].dt.year
        a['Month'] = a['review_date'].dt.month
        out_t_sent = pd.concat([out_t_sent,a])
# Out:
# /Users/devanshg/saas/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#colu = ["Brand_name","TotalPositive__Reviews","Month","Year"]
#out_t_sent.columns=colu
lis= ['maybelline','loreal','lakme','mac','colorbar']
out_t_sent = out_t_sent[out_t_sent['Brand_name'].isin(lis)]
out_t_sent.to_csv("2_positive_percentage_fragmentswise_for_last_year_lipsticks_new.csv",index=False)

# %%
i=1
out_t_all=pd.DataFrame()
map_comp_tree = out_prod_tree_date.company.unique()
#print map_comp_tree
for c in map_comp_tree:
    i=0
   # print c
    comp_rev = out_prod_tree_date[out_prod_tree_date.company == c]
    comp_rev['review_date'] =pd.to_datetime(comp_rev['review_date'])
    date_df= comp_rev.sort_values(by='review_date')
    a = date_df[date_df.review_date  > '2017-01-02']
    if a.empty:
        continue
    else:
       # print a['review_date']
        a = a['review_date'].groupby(a.review_date.dt.to_period("M")).agg('count')
        a = pd.DataFrame(a).rename(columns={'review_date':'Total_Number_of_Reviews'}).reset_index(drop=False)
        a['Brand_name'] = c
        
        a['Year'] = a['review_date'].dt.year
        a['Month'] = a['review_date'].dt.month
        out_t_all = pd.concat([out_t_all,a])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-9d70bf93e3c9> in <module>()
#       1 i=1
#       2 out_t_all=pd.DataFrame()
# ----> 3 map_comp_tree = out_prod_tree_date.company.unique()
#       4 #print map_comp_tree
#       5 for c in map_comp_tree:
#
# /Users/devanshg/saas/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'company'

# %%
#df4 = out_t_sent.merge(out_t_all, left_on='review_date', right_on='review_date')
df4 = pd.merge(out_t_sent, out_t_all[['review_date','Brand_name','Total_Number_of_Reviews']],  how='left', left_on=['review_date','Brand_name'], right_on = ['review_date','Brand_name'])
df4=df4.drop_duplicates()

# %%
out_prod_tree_date = pd.merge(tree)

# %%
final = []
for row in df4.to_dict('records'):
    row['positive percentage'] = float(row['Total_Number_of_PositiveReviews']/float(row['Total_Number_of_Reviews']))*100
    final.append(row)
final =pd.DataFrame(final)

# %%
final.to_csv("2_positive_percentage_fragmentswise_for_last_year_lipsticks_new.csv",index=False)

# %%
i=1
out_prod_tree_date['review_date'] =pd.to_datetime(out_prod_tree_date['review_date'])
out_prod_tree_date= out_prod_tree_date.sort_values(by='review_date')
out_prod_tree_date =out_prod_tree_date[out_prod_tree_date.review_date  > '2017-01-02']
out_prod_tree_date = out_prod_tree_date[out_prod_tree_date['company'].isin(lis)]
out_t_sent_rank=[]
map_comp_tree = out_prod_tree_date.company.unique()
comp_map_source = out_prod_tree_date.source.unique()
#print map_comp_tree
colu = ["Brand_name","Total_positive_fragments","Total_review_fragments","Total_positive percentage"]
for s in comp_map_source:
    if s == 1:
        source = "Flipkart"
        total_pos = "Flipkart_total_positive"
        total_src ="Flipkart_total_reviews"
    if s == 3:
        source = "Amazon"
        total_pos = "Amazon_total_positive"
        total_src ="Amazon_total_reviews"
    if s == 5:
        source = "Nyka"
        total_pos = "Nyka_total_positive"
        total_src ="Nyka_total_reviews"

    colu.append(total_pos)
    colu.append(source)
    colu.append(total_src)

# %%
out_prod_tree_date
# Out:
#                                   source_review_id  product_id  \
# 174677                                  rev_461841    100081.0
# 174678                                  rev_461841    100081.0
# 171287                              R1RVPO8TNA6M3F         NaN
# 17628         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17627         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17626         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 203849                              R258O3MSRV3F3I         NaN
# 97214                                   rev_461249    100034.0
# 171286                              R1RVPO8TNA6M3F         NaN
# 143621                                  rev_461479    100036.0
# 175421                                  rev_461801    100079.0
# 17652         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17653         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17654         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17636         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17635         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17655         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17634         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17633         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17632         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 143623                                  rev_461479    100036.0
# 151126        426ca03e-040a-4f0c-9b93-3dda386c0a84         NaN
# 143622                                  rev_461479    100036.0
# 181932  0159651e8b5f0000a17bf0481cab84ac_reviewDiv         NaN
# 168772        0c85987e-b17f-4efc-85d9-f54d6b3054e3         NaN
# 119470                              R3E8X4ALAYY5WI         NaN
# 119469                              R3E8X4ALAYY5WI         NaN
# 17631         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 17630         20935bf5-d50b-46da-8adb-9d302856e024         NaN
# 175424                                  rev_461801    100079.0
# ...                                            ...         ...
# 18627         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18628         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18654         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18653         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18652         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18651         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18650         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18649         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18648         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18647         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18646         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18645         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18644         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18643         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18656         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18642         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18640         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18639         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18638         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18637         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18636         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18635         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18634         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18633         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18632         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18631         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18630         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18629         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 18641         a1b73810-833a-4fa7-961d-1b025aaace0b         NaN
# 105157        a4e577f0-1f01-486d-ad56-60ec2e7e410f         NaN
#
#                   aspect                                     sentiment_text  \
# 174677          service               thanks nykaa for launching mac online
# 174678            style                      girl should try this beautiful
# 171287       durability                            not smear during the day
# 17628     ease-of-usage                                              smooth
# 17627     ease-of-usage                                              smooth
# 17626     ease-of-usage                                              smooth
# 203849            style                                           best look
# 97214    effect-on-skin                                    best indian skin
# 171286          service                        packaging is quite beautiful
# 143621   effect-on-skin   surely a must try colour for wheatish complexions
# 175421          service                  happy to see mac products at nykaa
# 17652             style                                     bold kajal look
# 17653             style                                     bold kajal look
# 17654             style                                     bold kajal look
# 17636     ease-of-usage                                              smooth
# 17635     ease-of-usage                                              smooth
# 17655             style                                     bold kajal look
# 17634     ease-of-usage                                              smooth
# 17633     ease-of-usage                                              smooth
# 17632     ease-of-usage                                              smooth
# 143623            style   surely a must try colour for wheatish complexions
# 151126          service                                                fake
# 143622            style                            surely a must try colour
# 181932       durability                             not at all long lasting
# 168772              vfm                                         combo worth
# 119470       durability      not good and very poor quality , does not stay
# 119469      reliability                      not good and very poor quality
# 17631     ease-of-usage                                              smooth
# 17630     ease-of-usage                                              smooth
# 175424            style                      love mac and love matte shades
# ...                  ...                                                ...
# 18627             style                                    brown is magical
# 18628             style                                    brown is magical
# 18654             style                                    brown is magical
# 18653             style                                    brown is magical
# 18652             style                                    brown is magical
# 18651             style                                    brown is magical
# 18650             style                                    brown is magical
# 18649             style                                    brown is magical
# 18648             style                                    brown is magical
# 18647             style                                    brown is magical
# 18646             style                                    brown is magical
# 18645             style                                    brown is magical
# 18644             style                                    brown is magical
# 18643             style                                    brown is magical
# 18656             style                                    brown is magical
# 18642             style                                    brown is magical
# 18640             style                                    brown is magical
# 18639             style                                    brown is magical
# 18638             style                                    brown is magical
# 18637             style                                    brown is magical
# 18636             style                                    brown is magical
# 18635             style                                    brown is magical
# 18634             style                                    brown is magical
# 18633             style                                    brown is magical
# 18632             style                                    brown is magical
# 18631             style                                    brown is magical
# 18630             style                                    brown is magical
# 18629             style                                    brown is magical
# 18641             style                                    brown is magical
# 105157      reliability                                good quality product
#
#         review_text_tag_ind  start_index  end_index  confidence-score  \
# 174677                  NaN           79        116          0.995168
# 174678                  NaN            6         36          0.994061
# 171287                  NaN          111        135          0.620690
# 17628                   NaN           38         44          0.999999
# 17627                   NaN           38         44          0.999999
# 17626                   NaN           38         44          0.999999
# 203849                  NaN            0          9          0.999978
# 97214                   NaN           53         69          0.999529
# 171286                  NaN           17         45          0.975222
# 143621                  NaN            0         49          0.996675
# 175421                  NaN            8         42          0.957939
# 17652                   NaN           62         77          0.999999
# 17653                   NaN           62         77          0.999999
# 17654                   NaN           62         77          0.999999
# 17636                   NaN           38         44          0.999999
# 17635                   NaN           38         44          0.999999
# 17655                   NaN           62         77          0.999999
# 17634                   NaN           38         44          0.999999
# 17633                   NaN           38         44          0.999999
# 17632                   NaN           38         44          0.999999
# 143623                  NaN            0         49          0.996675
# 151126                  NaN            0          4          0.999969
# 143622                  NaN            0         24          0.996675
# 181932                  NaN            8         31          0.384257
# 168772                  NaN          419        430          0.029617
# 119470                  NaN           34         79          0.000061
# 119469                  NaN           34         64          0.000061
# 17631                   NaN           38         44          0.999999
# 17630                   NaN           38         44          0.999999
# 175424                  NaN          126        156          0.999242
# ...                     ...          ...        ...               ...
# 18627                   NaN           39         55          0.952306
# 18628                   NaN           39         55          0.952306
# 18654                   NaN           39         55          0.952306
# 18653                   NaN           39         55          0.952306
# 18652                   NaN           39         55          0.952306
# 18651                   NaN           39         55          0.952306
# 18650                   NaN           39         55          0.952306
# 18649                   NaN           39         55          0.952306
# 18648                   NaN           39         55          0.952306
# 18647                   NaN           39         55          0.952306
# 18646                   NaN           39         55          0.952306
# 18645                   NaN           39         55          0.952306
# 18644                   NaN           39         55          0.952306
# 18643                   NaN           39         55          0.952306
# 18656                   NaN           39         55          0.952306
# 18642                   NaN           39         55          0.952306
# 18640                   NaN           39         55          0.952306
# 18639                   NaN           39         55          0.952306
# 18638                   NaN           39         55          0.952306
# 18637                   NaN           39         55          0.952306
# 18636                   NaN           39         55          0.952306
# 18635                   NaN           39         55          0.952306
# 18634                   NaN           39         55          0.952306
# 18633                   NaN           39         55          0.952306
# 18632                   NaN           39         55          0.952306
# 18631                   NaN           39         55          0.952306
# 18630                   NaN           39         55          0.952306
# 18629                   NaN           39         55          0.952306
# 18641                   NaN           39         55          0.952306
# 105157                  NaN            0         20          0.996518
#
#        source_product_id        treemap_name  category_id sentiment_type  \
# 174677             90470             online             1       positive
# 174678             90470               girl             1       positive
# 171287        B0079Z0AMM                day             1       positive
# 17628   KJLDQX983DGXDFG8             smooth             1       positive
# 17627   KJLDQX983DGXDFG8             smooth             1       positive
# 17626   KJLDQX983DGXDFG8             smooth             1       positive
# 203849        B00D161WOI               look             1       positive
# 97214               7588        indian_skin             1       positive
# 171286        B0079Z0AMM          packaging             1       positive
# 143621              2145        complexions             1       positive
# 175421             90344              nykaa             1       positive
# 17652   KJLEC9MUD8KKHJFQ               look             1       positive
# 17653   KJLEC9MUD8KKHJFQ               look             1       positive
# 17654   KJLEC9MUD8KKHJFQ               look             1       positive
# 17636   KJLEC9MUD8KKHJFQ             smooth             1       positive
# 17635   KJLEC9MUD8KKHJFQ             smooth             1       positive
# 17655   KJLEC9MUD8KKHJFQ               look             1       positive
# 17634   KJLEC9MUD8KKHJFQ             smooth             1       positive
# 17633   KJLEC9MUD8KKHJFQ             smooth             1       positive
# 17632   KJLEC9MUD8KKHJFQ             smooth             1       positive
# 143623              2145        complexions             1       positive
# 151126  KJLDADR2RVFGEFY4               fake             1       negative
# 143622              2145             colour             1       positive
# 181932      677019119829   NEG_long_lasting             1       negative
# 168772  KJLE2DAJUF7KADCQ              combo             1       negative
# 119470        B006LXBSYM               stay             1       positive
# 119469        B006LXBSYM            quality             1       positive
# 17631   KJLDQX983DGXDFG8             smooth             1       positive
# 17630   KJLDQX983DGXDFG8             smooth             1       positive
# 175424             90344             shades             1       positive
# ...                  ...                 ...          ...            ...
# 18627   KJLEJ27FQGPHJD5F              brown             1       positive
# 18628   KJLEJ27FQGPHJD5F              brown             1       positive
# 18654   KJLEJ27FQK3RZCNC              brown             1       positive
# 18653   KJLEJ27FQK3RZCNC              brown             1       positive
# 18652   KJLEJ27FQK3RZCNC              brown             1       positive
# 18651   KJLEJ27FQK3RZCNC              brown             1       positive
# 18650   KJLEJ27FQK3RZCNC              brown             1       positive
# 18649   KJLEJ27FQK3RZCNC              brown             1       positive
# 18648   KJLEJ27FQK3RZCNC              brown             1       positive
# 18647   KJLEJ27FQK3RZCNC              brown             1       positive
# 18646   KJLEJ27FQK3RZCNC              brown             1       positive
# 18645   KJLEJ27FQK3RZCNC              brown             1       positive
# 18644   KJLEJ27FQK3RZCNC              brown             1       positive
# 18643   KJLEJ27FQK3RZCNC              brown             1       positive
# 18656   KJLEJ27FQK3RZCNC              brown             1       positive
# 18642   KJLEJ27FQK3RZCNC              brown             1       positive
# 18640   KJLEJ27FQK3RZCNC              brown             1       positive
# 18639   KJLEJ27FQK3RZCNC              brown             1       positive
# 18638   KJLEJ27FQK3RZCNC              brown             1       positive
# 18637   KJLEJ27FQK3RZCNC              brown             1       positive
# 18636   KJLEJ27FQGPHJD5F              brown             1       positive
# 18635   KJLEJ27FQGPHJD5F              brown             1       positive
# 18634   KJLEJ27FQGPHJD5F              brown             1       positive
# 18633   KJLEJ27FQGPHJD5F              brown             1       positive
# 18632   KJLEJ27FQGPHJD5F              brown             1       positive
# 18631   KJLEJ27FQGPHJD5F              brown             1       positive
# 18630   KJLEJ27FQGPHJD5F              brown             1       positive
# 18629   KJLEJ27FQGPHJD5F              brown             1       positive
# 18641   KJLEJ27FQK3RZCNC              brown             1       positive
# 105157  KJLDRG34G6PRGGUU    quality_product             1       positive
#
#        review_date     company  source
# 174677  2017-01-03         mac       5
# 174678  2017-01-03         mac       5
# 171287  2017-01-03  maybelline       3
# 17628   2017-01-03      loreal       1
# 17627   2017-01-03      loreal       1
# 17626   2017-01-03      loreal       1
# 203849  2017-01-03  maybelline       3
# 97214   2017-01-03    colorbar       5
# 171286  2017-01-03  maybelline       3
# 143621  2017-01-03    colorbar       5
# 175421  2017-01-03         mac       5
# 17652   2017-01-03      loreal       1
# 17653   2017-01-03      loreal       1
# 17654   2017-01-03      loreal       1
# 17636   2017-01-03      loreal       1
# 17635   2017-01-03      loreal       1
# 17655   2017-01-03      loreal       1
# 17634   2017-01-03      loreal       1
# 17633   2017-01-03      loreal       1
# 17632   2017-01-03      loreal       1
# 143623  2017-01-03    colorbar       5
# 151126  2017-01-03  maybelline       1
# 143622  2017-01-03    colorbar       5
# 181932  2017-01-03      loreal       3
# 168772  2017-01-03  maybelline       1
# 119470  2017-01-03       lakme       3
# 119469  2017-01-03       lakme       3
# 17631   2017-01-03      loreal       1
# 17630   2017-01-03      loreal       1
# 175424  2017-01-03         mac       5
# ...            ...         ...     ...
# 18627   2018-01-10       lakme       1
# 18628   2018-01-10       lakme       1
# 18654   2018-01-10       lakme       1
# 18653   2018-01-10       lakme       1
# 18652   2018-01-10       lakme       1
# 18651   2018-01-10       lakme       1
# 18650   2018-01-10       lakme       1
# 18649   2018-01-10       lakme       1
# 18648   2018-01-10       lakme       1
# 18647   2018-01-10       lakme       1
# 18646   2018-01-10       lakme       1
# 18645   2018-01-10       lakme       1
# 18644   2018-01-10       lakme       1
# 18643   2018-01-10       lakme       1
# 18656   2018-01-10       lakme       1
# 18642   2018-01-10       lakme       1
# 18640   2018-01-10       lakme       1
# 18639   2018-01-10       lakme       1
# 18638   2018-01-10       lakme       1
# 18637   2018-01-10       lakme       1
# 18636   2018-01-10       lakme       1
# 18635   2018-01-10       lakme       1
# 18634   2018-01-10       lakme       1
# 18633   2018-01-10       lakme       1
# 18632   2018-01-10       lakme       1
# 18631   2018-01-10       lakme       1
# 18630   2018-01-10       lakme       1
# 18629   2018-01-10       lakme       1
# 18641   2018-01-10       lakme       1
# 105157  2018-01-10       lakme       1
#
# [79592 rows x 15 columns]

# %%
for c in map_comp_tree:
    comp_rev = out_prod_tree_date[out_prod_tree_date.company == c]
    total = len(comp_rev.index)
    #print total
    #comp_rev_source = comp_rev.source_y.unique()
    comp_rev_pos = comp_rev[comp_rev.sentiment_type == 'positive']
    total_pos = len(comp_rev_pos.index)
    if total == 0:
        total =1
    row2 = [c,total_pos,total,float(total_pos/float(total))]
    for s in comp_map_source:
        comp_rev_source_1 = comp_rev[comp_rev.source == s]
        
        total_source = len(comp_rev_source_1.index)
        if total_source == 0:
            comp_rev_pos_source = comp_rev_source_1[comp_rev_source_1.sentiment_type == 'positive']
            total_pos_source = len(comp_rev_pos_source.index)
            row2.append(total_pos)
            row2.append(0)
            row2.append(0)
        else:    
            comp_rev_pos_source = comp_rev_source_1[comp_rev_source_1.sentiment_type == 'positive']
            total_pos_source = len(comp_rev_pos_source.index)
            row2.append(total_pos_source)
            row2.append(float(total_pos_source/float(total_source))*100)
            row2.append((total_source))
    out_t_sent_rank.append(row2)
out_t_sent_rank=pd.DataFrame(out_t_sent_rank)        
out_t_sent_rank.columns=colu
out_t_sent_rank.to_csv("4_task_positive_percentage_lipstick_source_wise2.csv",index=False)

# %%
out_t_sent_rank.to_csv("4_task_positive_percentage_lipstick_source_rank.csv",index=False)

# %%
out_t_sent_rank['Total_positive_fragments'].sum()
# Out:
# 85088

# %%
import numpy as np
df = pd.DataFrame({'a': [1, 10, 8, 11, -1],
                 'b': list('abdce'),
                 'c': [1.0, 2.0, np.nan, 3.0, 4.0]})

# %%
df.nlargest(3, 'a')
# Out:
#     a  b    c
# 3  11  c  3.0
# 1  10  b  2.0
# 2   8  d  NaN
