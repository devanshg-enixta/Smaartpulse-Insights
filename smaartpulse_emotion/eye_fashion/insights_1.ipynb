# %%
import pandas as pd

# %%
source = pd.read_csv("eye_fashion_source_reviews_new_19-1-2018.txt",sep='~')
tree = pd.read_csv("treemap_outputfile_mapped_2018-1-25_eye_fashion_sentiment_hul.txt",sep='~')

# %%
source=source.drop_duplicates()
del tree['source']

# %%
tree=tree.drop_duplicates()

# %%
out_prod=[]
for row in source.to_dict("records"):
    row['product_name'] = row['product_name'].lower()
    row['product_name'] = row['product_name'].replace("l'oreal","loreal").replace('l-oreal',"loreal").replace('e-l-f',"elf").replace('v-color',"").replace('m-n-mn',"mn").replace('m-a-c',"mac").replace('k-veda',"KVeda").replace('l-a-girl',"l_a_girl").replace('7-heaven',"7_heaven").replace('7heavens',"7_heaven").replace('7-heavens',"7_heaven").replace('c-a-l-los-angeles',"c_a_l_los_angeles").replace('c-l-los-angeles',"c_a_l_los_angeles").replace(" ","-").lower()
    x = row['product_name'].split('-', 1)
    #x = x.split(' ')
    row['company'] = x[0].lower()
    out_prod.append(row)
mapped_comp_source=pd.DataFrame(out_prod)

# %%
mapped_comp = mapped_comp_source.company.unique()

# %%
import calendar
import datetime
import dateutil
today = datetime.datetime.now()
i=1
out_t=[]
colum = ["Brand_name","Trend_Total_Reviews","Month","Year"]
for c in mapped_comp:
    print c
    cnt_p = 0
    cnt = 0
    cnt_n=0
    comp_rev = mapped_comp_source[mapped_comp_source.company == c]
    company = c
    for i in range (1,13):
        cnt =0
#        cnt_p =0
 #       cnt_n=0
        for row in comp_rev.to_dict("records"):
            dt = dateutil.parser.parse(row['review_date'])
            if dt.year == today.year - 1:
                year = dt.year
                if dt.month == i:
                    #if row['sentiment_type'].strip() == 'negative':
                     #   cnt_n = cnt_n+1
                    #else:
                      #  cnt_p =cnt_p+1
                    cnt = cnt +1
        if cnt > 0 :
            row2 = [company,cnt,i,year]#,float(cnt_p/float(cnt))*100]
            out_t.append(row2)
out_t=pd.DataFrame(out_t)        
out_t.columns=colum
# Out:
# revlon
# lotus
# colorbar
# maybelline
# loreal
# coloressence
# lakme
# clinique
# elf
# anna
# meilin
# cameleon
# chambor
# avon
# lancome
# teen
# glam
# amura
# kudos
# kveda
# blue
# mn
# diana
# cover
# faces
# cal
# hilary
# c_a_l_los_angeles
# rimmel
# 7_heaven
# mars
# ads
# music
# me
# essence
# makeup
# meylon
# bobbi
# glamcom
# hr
# incolor
# celebrity
# hope
# out
# natio
# one
# beauty
# oriflame
# castillo
# insight
# maybeline
# forteens
#
# menow
# glam21
# makeover
# max
# body
# stargazer
# star
# deborah
# sivanna
# nicka
# urban
# br
# qumeidie
# miss
# kiss
# cameo
# mua
# balm
# nyx
# freedom
# color4ever
# insiti
# mac
# laura
# arezia
# n
# vlcc
# shahnaz
# soultree
# iba
# brndey
# plum
# pac
# glitters
# color
# high
# m
# bonjour
# estee
# ambitione
# ramose
# personi
# elizabeth
# vov
# covergirl
# leol
# smolder
# benefit
# black
# ultra
# kodiake
# chantecaille
# italia
# eucerin
# inglot
# schwing
# lorac
# l
# bourjois
# biotique
# elle
# emaxdesign
# extreme
# transparent
# girl
# simply
# moisturising
# elle18
# heavens
# jovees
# great
# heaven
# hittime
# nelf
# mahavir
# now
# eyeliner
# aloe
# my
# neev
# evuar
# liner
# long
# eye
# perfect
# elenblu
# colors
# invisible
# 600pcs
# smokey
# c2p
# fashion
# kajal
# patanjali
# roseleaf
# stars
# swiss
# vozwa
# 7_heavens
# combo
# glams
# himalayaka
# himalaya
# milani
# thebalm
# nykaa
# absolute
# wet
# l_a_girl
# garnier
# mib
# buy
# innisfree
# australis
# the
# street
# sugar
# ardell
# bharat
# ciate
# fabindia
# freshlook
# gala
# lord

# %%
out_t.to_csv("1_task_12_months_review_brand_wise_eye_fashion.csv",index=False)

# %%
out_prod_tree_date = tree.merge(mapped_comp_source, left_on='source_review_id', right_on='source_review_id')

# %%
del out_prod_tree_date['source_product_id_y']

# %%
out_prod_tree_date=out_prod_tree_date.drop_duplicates()

# %%
i=1
out_t_sent=[]
map_comp_tree = out_prod_tree_date.company.unique()
#print map_comp_tree
colum = ["Brand_name","Trend_Total_Reviews","Month","Year","%positive"]
for c in map_comp_tree:
    print c
    cnt_p = 0
    cnt = 0
    cnt_n=0
    comp_rev = out_prod_tree_date[out_prod_tree_date.company == c]
    company = c
    for i in range (1,13):
        cnt =0
        cnt_p =0
        cnt_n=0
        for row in comp_rev.to_dict("records"):
            dt = dateutil.parser.parse(row['review_date'])
            if dt.year == today.year - 1:
                year = dt.year
                if dt.month == i:
                    if row['sentiment_type'].strip() == 'negative':
                        cnt_n = cnt_n+1
                    else:
                        cnt_p =cnt_p+1
                    cnt = cnt +1
        if cnt > 0 :
            row2 = [company,cnt,i,year,float(cnt_p/float(cnt))*100]
            out_t_sent.append(row2)
out_t_sent=pd.DataFrame(out_t_sent)        
out_t_sent.columns=colum
# Out:
# revlon
# colorbar
# maybelline
# loreal
# coloressence
# lakme
# cameleon
# chambor
# teen
# glam
# kveda
# mn
# diana
# lotus
# hilary
# rimmel
# 7_heaven
# music
# faces
# kudos
# me
# hr
# mars
# meilin
# incolor
# hope
# avon
# essence
# c_a_l_los_angeles
# oriflame
# castillo
# ads
# blue
# insight
# maybeline
#
# glam21
# forteens
# max
# deborah
# star
# sivanna
# br
# makeup
# mua
# balm
# freedom
# arezia
# vlcc
# shahnaz
# mac
# soultree
# iba
# plum
# glitters
# high
# bonjour
# amura
# cover
# personi
# smolder
# bobbi
# nyx
# elf
# kodiake
# inglot
# l
# natio
# biotique
# elle
# emaxdesign
# color
# extreme
# transparent
# girl
# simply
# kiss
# beauty
# heavens
# covergirl
# eyeliner
# neev
# liner
# long
# elenblu
# colors
# 600pcs
# smokey
# menow
# patanjali
# roseleaf
# stars
# 7_heavens
# anna
# milani
# nykaa
# wet
# l_a_girl
# garnier
# nicka
# himalaya
# pac
# mib
# buy
# innisfree
# thebalm
# australis
# the
# street
# sugar
# ardell
# bharat
# ciate
# fabindia
# freshlook
# gala
# lord
# qumeidie
# miss
# cameo
# color4ever
# meylon
# brndey
# estee
# vov
# chantecaille
# eucerin
# jovees
# heaven
# mahavir
# evuar
# vozwa
# glams
# himalayaka
# clinique
# lancome
# glamcom
# celebrity
# out
# body
# urban
# leol
# benefit
# great
# aloe
# my
# eye
# perfect
# fashion
# kajal
# combo
# cal
# one
# makeover
# insiti
# laura
# n
# m
# ambitione
# ramose
# elizabeth
# black
# italia
# schwing
# moisturising
# hittime
# now
# elle18
# invisible
# nelf
# c2p
# swiss
# ultra
# lorac
# absolute

# %%
colu = ["Brand_name","TotalPositive__Reviews","Month","Year","positive"]
out_t_sent.columns=colu
out_t_sent.to_csv("2_positive_percentage_fragmentswise_for_last_year_eye_fashion.csv",index=False)

# %%
i=1
out_t_sent_rank=[]
map_comp_tree = out_prod_tree_date.company.unique()
comp_map_source = out_prod_tree_date.source.unique()
#print map_comp_tree
colu = ["Brand_name","Trend_Total_Reviews_positive","Total_review_fragments"]
for s in comp_map_source:
    if s == 1:
        source = "Flipkart"
        total_pos = "Flipkart_total_positive"
    if s == 3:
        source = "Amazon"
        total_pos = "Amazon_total_positive"
    if s == 5:
        source = "Nyka"
        total_pos = "Nyka_total_positive"

    colu.append(total_pos)
    colu.append(source)


for c in map_comp_tree:
    comp_rev = out_prod_tree_date[out_prod_tree_date.company == c]
    total = len(comp_rev.index)
    #comp_rev_source = comp_rev.source_y.unique()
    comp_rev_pos = comp_rev[comp_rev.sentiment_type == 'positive']
    total_pos = len(comp_rev_pos.index)
    row2 = [c,total_pos,total]
    for s in comp_map_source:
        comp_rev_source_1 = comp_rev[comp_rev.source == s]
        total_source = len(comp_rev_source_1.index)
        if total_pos == 0:
            comp_rev_pos_source = comp_rev_source_1[comp_rev_source_1.sentiment_type == 'positive']
            total_pos_source = len(comp_rev_pos_source.index)
            row2.append(total_pos)
            row2.append(0)
        else:    
            comp_rev_pos_source = comp_rev_source_1[comp_rev_source_1.sentiment_type == 'positive']
            total_pos_source = len(comp_rev_pos_source.index)
            row2.append(total_pos_source)
            row2.append(float(total_pos_source/float(total_pos)))
    out_t_sent_rank.append(row2)
out_t_sent_rank=pd.DataFrame(out_t_sent_rank)        
out_t_sent_rank.columns=colu
out_t_sent_rank.to_csv("4_task_positive_percentage_eye_fashion_source_wise.csv",index=False)

# %%
mapped_comp_source[mapped_comp_source.source_review_id=='fc331094-d097-4339-9dd7-4b5839dffbb6']
# Out:
#   company                                       product_name   review_date  \
# 1  revlon  revlon-photo-ready-kajal-intense-eye-liner-bri...  19 Apr, 2015
#
#    review_tag                                        review_text  \
# 1         NaN  great colour, glides on smoothly without any h...
#
#                                           review_url reviewer_name  source  \
# 1  http://www.flipkart.com/reviews/fc331094-d097-...        Shikha       1
#
#   source_product_id                      source_review_id star_rating  \
# 1  ELRD96GN3WE3BCYP  fc331094-d097-4339-9dd7-4b5839dffbb6           4
#
#   verified_user
# 1          True
